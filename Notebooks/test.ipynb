# %%
import sys
import numpy as np
import pandas as pd

print(sys.executable)
print(np.__version__)
print(pd.__version__)
# Out:
# c:\Users\johnw\Documents\PhD\.venv\Scripts\python.exe
# 2.4.1
# 2.3.3
